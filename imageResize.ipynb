# %%
from PIL import Image
import os
import imageio
from helper import utilty

# %%
path = "data/0.25@0.25km_train/"
dirs = os.listdir( path )

for item in dirs:
    if os.path.isfile(path+item):
      img = utilty.load_image(path+item)
      img = utilty.resize_image_by_pil(img,0.25)
      utilty.save_image('data/1km_train/'+item.replace('0.25km','1km'),img)
# Out:
# Loaded [data/0.25@0.25km_train/0.25@0.25km_jamnagar_D73_H12.0.tif]: 800 x 720 x 1
# Saved [data/1km_train/0.25@1km_jamnagar_D73_H12.0.tif]
# Loaded [data/0.25@0.25km_train/0.25@0.25km_jamnagar_D45_H12.5.tif]: 800 x 720 x 1
# Saved [data/1km_train/0.25@1km_jamnagar_D45_H12.5.tif]
# Loaded [data/0.25@0.25km_train/0.25@0.25km_jamnagar_D81_H12.0.tif]: 800 x 720 x 1
# Saved [data/1km_train/0.25@1km_jamnagar_D81_H12.0.tif]
# Loaded [data/0.25@0.25km_train/0.25@0.25km_jamnagar_D3_H12.5.tif]: 800 x 720 x 1
# Saved [data/1km_train/0.25@1km_jamnagar_D3_H12.5.tif]
# Loaded [data/0.25@0.25km_train/0.25@0.25km_jamnagar_D72_H12.5.tif]: 800 x 720 x 1
# Saved [data/1km_train/0.25@1km_jamnagar_D72_H12.5.tif]
# Loaded [data/0.25@0.25km_train/0.25@0.25km_jamnagar_D27_H14.0.tif]: 800 x 720 x 1
# Saved [data/1km_train/0.25@1km_jamnagar_D27_H14.0.tif]
# Loaded [data/0.25@0.25km_train/0.25@0.25km_jamnagar_D14_H14.0.tif]: 800 x 720 x 1
# Saved [data/1km_train/0.25@1km_jamnagar_D14_H14.0.tif]
# ...
